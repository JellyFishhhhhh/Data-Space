# %%
import pandas as pd
import numpy as np
thisdf = pd.read_excel("../project data/UN_MigrantStockTotal_2015.xlsx",sheet_name="Table 4",skiprows=14)
thisdf
# Out:
#      Sort\norder Major area, region, country or area of destination Notes  \
# 0            NaN                                                NaN   NaN
# 1            1.0                                              WORLD   NaN
# 2            2.0                                  Developed regions   (b)
# 3            3.0                                 Developing regions   (c)
# 4            4.0                          Least developed countries   (d)
# ..           ...                                                ...   ...
# 261        261.0                                              Samoa   NaN
# 262        262.0                                            Tokelau   NaN
# 263        263.0                                              Tonga   NaN
# 264        264.0                                             Tuvalu   NaN
# 265        265.0                          Wallis and Futuna Islands   NaN
#
#      Country code Type of data (a)  \
# 0             NaN              NaN
# ...

# %%
thisdf = thisdf.rename(columns={"Female migrants as a percentage of the international migrant stock" : "21990", "Unnamed: 6" : "21995","Unnamed: 7" : "22000","Unnamed: 8" : "22005","Unnamed: 9" : "22010","Unnamed: 10":"22015"})
thisdf1 = thisdf[1:]
thisdf1
# Out:
#      Sort\norder Major area, region, country or area of destination Notes  \
# 1            1.0                                              WORLD   NaN
# 2            2.0                                  Developed regions   (b)
# 3            3.0                                 Developing regions   (c)
# 4            4.0                          Least developed countries   (d)
# 5            5.0  Less developed regions excluding least develop...   NaN
# ..           ...                                                ...   ...
# 261        261.0                                              Samoa   NaN
# 262        262.0                                            Tokelau   NaN
# 263        263.0                                              Tonga   NaN
# 264        264.0                                             Tuvalu   NaN
# 265        265.0                          Wallis and Futuna Islands   NaN
#
#      Country code Type of data (a)      21990      21995      22000  \
# ...

# %%
thisdf1 = thisdf1.melt(id_vars=["Sort\norder","Major area, region, country or area of destination","Notes","Country code","Type of data (a)"],var_name=["temp"],value_name="Percentage of the international migrant stock")
thisdf1
# Out:
#       Sort\norder Major area, region, country or area of destination Notes  \
# 0             1.0                                              WORLD   NaN
# 1             2.0                                  Developed regions   (b)
# 2             3.0                                 Developing regions   (c)
# 3             4.0                          Least developed countries   (d)
# 4             5.0  Less developed regions excluding least develop...   NaN
# ...           ...                                                ...   ...
# 1585        261.0                                              Samoa   NaN
# 1586        262.0                                            Tokelau   NaN
# 1587        263.0                                              Tonga   NaN
# 1588        264.0                                             Tuvalu   NaN
# 1589        265.0                          Wallis and Futuna Islands   NaN
#
#       Country code Type of data (a)   temp  \
# ...

# %%
thisdf1 = thisdf1.assign(Gender = lambda x : x.temp.str[0], Year = lambda x : x.temp.str[1:])
#if rerun, rerun previous block first (because of pop function)
thisdf1.pop("temp")
thisdf1 = thisdf1.replace(to_replace=["0","1","2"],value=["both","male","female"])
thisdf1
# Out:
#       Sort\norder Major area, region, country or area of destination Notes  \
# 0             1.0                                              WORLD   NaN
# 1             2.0                                  Developed regions   (b)
# 2             3.0                                 Developing regions   (c)
# 3             4.0                          Least developed countries   (d)
# 4             5.0  Less developed regions excluding least develop...   NaN
# ...           ...                                                ...   ...
# 1585        261.0                                              Samoa   NaN
# 1586        262.0                                            Tokelau   NaN
# 1587        263.0                                              Tonga   NaN
# 1588        264.0                                             Tuvalu   NaN
# 1589        265.0                          Wallis and Futuna Islands   NaN
#
#       Country code Type of data (a)  \
# ...

# %%
thisdf1["Sort\norder"] = thisdf1["Sort\norder"].astype('int64')
thisdf1["Country code"] = thisdf1["Country code"].astype('int64')
thisdf4 = thisdf1
thisdf1
# Out:
#       Sort\norder Major area, region, country or area of destination Notes  \
# 0               1                                              WORLD   NaN
# 1               2                                  Developed regions   (b)
# 2               3                                 Developing regions   (c)
# 3               4                          Least developed countries   (d)
# 4               5  Less developed regions excluding least develop...   NaN
# ...           ...                                                ...   ...
# 1585          261                                              Samoa   NaN
# 1586          262                                            Tokelau   NaN
# 1587          263                                              Tonga   NaN
# 1588          264                                             Tuvalu   NaN
# 1589          265                          Wallis and Futuna Islands   NaN
#
#       Country code Type of data (a)  \
# ...

# %%
thisdf1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1590 entries, 0 to 1589
# Data columns (total 8 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   Sort
# order                                          1590 non-null   int64
#  1   Major area, region, country or area of destination  1590 non-null   object
#  2   Notes                                               156 non-null    object
#  3   Country code                                        1590 non-null   int64
#  4   Type of data (a)                                    1392 non-null   object
#  5   Percentage of the international migrant stock       1590 non-null   object
#  6   Gender                                              1590 non-null   object
#  7   Year                                                1590 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 99.5+ KB

# %%
thisdf1 = thisdf1.replace(to_replace="..",value=0)

# %%
thisdf1["Percentage of the international migrant stock"] = thisdf1["Percentage of the international migrant stock"].astype(float)

# %%
thisdf1 = thisdf1.set_index(["Major area, region, country or area of destination","Notes","Country code","Type of data (a)","Percentage of the international migrant stock","Gender","Year"])

# %%
thisdf2 = pd.DataFrame.from_records(
    columns=["id","Major area, region, country or area of destination","Notes","Country code","Type of data (a)","Percentage of the international migrant stock","Gender","Year"],
    data = [(a,b,c,d,e,100-f,"male",h) for (a,(b,c,d,e,f,g,h)) in enumerate(thisdf1.index.unique())]
)

# %%
thisdf2
# Out:
#         id Major area, region, country or area of destination Notes  \
# 0        0                                              WORLD   NaN
# 1        1                                  Developed regions   (b)
# 2        2                                 Developing regions   (c)
# 3        3                          Least developed countries   (d)
# 4        4  Less developed regions excluding least develop...   NaN
# ...    ...                                                ...   ...
# 1585  1585                                              Samoa   NaN
# 1586  1586                                            Tokelau   NaN
# 1587  1587                                              Tonga   NaN
# 1588  1588                                             Tuvalu   NaN
# 1589  1589                          Wallis and Futuna Islands   NaN
#
#       Country code Type of data (a)  \
# 0              900              NaN
# 1              901              NaN
# 2              902              NaN
# ...

# %%
thisdf2["Percentage of the international migrant stock"] = thisdf2["Percentage of the international migrant stock"].replace(to_replace=100.0,value=np.nan)
thisdf2["Percentage of the international migrant stock"] = thisdf2["Percentage of the international migrant stock"].astype(str)

# %%
thisdf2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1590 entries, 0 to 1589
# Data columns (total 8 columns):
#  #   Column                                              Non-Null Count  Dtype
# ---  ------                                              --------------  -----
#  0   id                                                  1590 non-null   int64
#  1   Major area, region, country or area of destination  1590 non-null   object
#  2   Notes                                               156 non-null    object
#  3   Country code                                        1590 non-null   int64
#  4   Type of data (a)                                    1392 non-null   object
#  5   Percentage of the international migrant stock       1590 non-null   object
#  6   Gender                                              1590 non-null   object
#  7   Year                                                1590 non-null   object
# dtypes: int64(2), object(6)
# memory usage: 99.5+ KB

# %%
thisdf3 = pd.DataFrame.from_records(
    columns=["id","Major area, region, country or area of destination","Notes","Country code","Type of data (a)","Percentage of the international migrant stock","Gender","Year"],
    data = [(a,b,c,d,e,"100","both",h) for (a,(b,c,d,e,f,g,h)) in enumerate(thisdf1.index.unique())]
)

# %%
thisdf3
# Out:
#         id Major area, region, country or area of destination Notes  \
# 0        0                                              WORLD   NaN
# 1        1                                  Developed regions   (b)
# 2        2                                 Developing regions   (c)
# 3        3                          Least developed countries   (d)
# 4        4  Less developed regions excluding least develop...   NaN
# ...    ...                                                ...   ...
# 1585  1585                                              Samoa   NaN
# 1586  1586                                            Tokelau   NaN
# 1587  1587                                              Tonga   NaN
# 1588  1588                                             Tuvalu   NaN
# 1589  1589                          Wallis and Futuna Islands   NaN
#
#       Country code Type of data (a)  \
# 0              900              NaN
# 1              901              NaN
# 2              902              NaN
# ...

# %%
thisdf5 = thisdf3.merge(thisdf2,how="outer").merge(thisdf4,how="outer")
thisdf5.pop("id")
thisdf5.pop("Sort\norder")
thisdf5.pop("Country code")
# Out:
# 0       900
# 1       901
# 2       902
# 3       941
# 4       934
#        ...
# 4765    882
# 4766    772
# 4767    776
# 4768    798
# 4769    876
# Name: Country code, Length: 4770, dtype: int64

# %%
thisdf5 = thisdf5.replace(to_replace="..",value=np.nan)
#thisdf5[thisdf5["Gender"] == "female"].iloc[1:30]

# %%
thisdf5
# Out:
#      Major area, region, country or area of destination Notes  \
# 0                                                 WORLD   NaN
# 1                                     Developed regions   (b)
# 2                                    Developing regions   (c)
# 3                             Least developed countries   (d)
# 4     Less developed regions excluding least develop...   NaN
# ...                                                 ...   ...
# 4765                                              Samoa   NaN
# 4766                                            Tokelau   NaN
# 4767                                              Tonga   NaN
# 4768                                             Tuvalu   NaN
# 4769                          Wallis and Futuna Islands   NaN
#
#      Type of data (a) Percentage of the international migrant stock  Gender  \
# 0                 NaN                                           100    both
# ...

# %%
thisdf5.to_excel("percentageTable.xlsx")
